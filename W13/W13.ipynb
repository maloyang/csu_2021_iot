# %% [markdown]
# # MySQL應用：空氣污染指數aqi的趨勢圖

# %%
#mysql_db_url = 'mysql+pymysql://username:password@your-db-url:port/dbname'
mysql_db_url = 'mysql+pymysql://user1:ji3g4user1@206.189.86.205:32769/testdb'

# %% [markdown]
# - 要先安裝 mysql 的 driver

# %%
# !pip install PyMySQL
# Out:
# Requirement already satisfied: PyMySQL in c:\users\malo\anaconda3\lib\site-packages (0.10.0)
# WARNING: You are using pip version 21.1.2; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\malo\anaconda3\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# - 連接資料庫

# %%
from sqlalchemy import create_engine

my_db = create_engine(mysql_db_url)

# %% [markdown]
# - 讀取最新的資料庫

# %%
# select
resultProxy=my_db.execute("select * from malo_1030_aqi_table2 where uuid='鳳山' and time>='2021/11/23 00:00:00'")
data = resultProxy.fetchall()

# %%
len(data)
# Out:
# 9

# %%
for item in data:
    print(dict(item))
# Out:
# {'uuid': '鳳山', 'time': '2021/11/23 00:00:00', 'aqi': '70', 'pm25': '13'}
# {'uuid': '鳳山', 'time': '2021/11/23 01:00:00', 'aqi': '64', 'pm25': '16'}
# {'uuid': '鳳山', 'time': '2021/11/23 03:00:00', 'aqi': '55', 'pm25': '14'}
# {'uuid': '鳳山', 'time': '2021/11/23 04:00:00', 'aqi': '54', 'pm25': '13'}
# {'uuid': '鳳山', 'time': '2021/11/23 05:00:00', 'aqi': '54', 'pm25': '20'}
# {'uuid': '鳳山', 'time': '2021/11/23 06:00:00', 'aqi': '55', 'pm25': '20'}
# {'uuid': '鳳山', 'time': '2021/11/23 07:00:00', 'aqi': '55', 'pm25': '18'}
# {'uuid': '鳳山', 'time': '2021/11/23 08:00:00', 'aqi': '58', 'pm25': '23'}
# {'uuid': '鳳山', 'time': '2021/11/23 09:00:00', 'aqi': '61', 'pm25': '25'}

# %% [markdown]
# ## plot!

# %%
#先整理資料
time_list = []
hour_list = []
aqi_list = []
for item in data:
    time_list.append(item['time'])
    aqi_list.append(int(item['aqi']))
print(time_list)
print(aqi_list)
# Out:
# ['2021/11/23 00:00:00', '2021/11/23 01:00:00', '2021/11/23 03:00:00', '2021/11/23 04:00:00', '2021/11/23 05:00:00', '2021/11/23 06:00:00', '2021/11/23 07:00:00', '2021/11/23 08:00:00', '2021/11/23 09:00:00']
# [70, 64, 55, 54, 54, 55, 55, 58, 61]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(time_list, aqi_list)
plt.xlabel('time')
plt.ylabel('aqi')
plt.grid()

# %% [markdown]
# ### 圖上的x座標不能看!

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(time_list, aqi_list)
plt.xlabel('time')
plt.ylabel('aqi')
plt.xticks(time_list, rotation=90)
plt.grid()

# %% [markdown]
# ## TODO: 只顯示hour就好

# %%
# TODO:

# %% [markdown]
# ## TODO: 畫出最近7天的趨勢圖

# %% [markdown]
# ## TODO: 選擇其他監控站，並繪出趨勢圖，若能換成畫pm2.5更好
# ### 其他監控站點的清單:
# - 美濃
# - 橋頭
# - 仁武
# - 大寮
# - 林園
# - 左營
# - 前金
# - 前鎮
# - 小港
# - 復興
